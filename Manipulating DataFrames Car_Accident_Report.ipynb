# %%
import pandas as pd

# %%
import numpy as np

# %%
cart_df = pd.read_csv('/Users/christooicey/Downloads/archive-3/2015_State_Top10Report_wTotalThefts.csv')

# %%
car_df = pd.read_csv('/Users/christooicey/Downloads/archive-3/Top25-2015-Models-2015-thefts-for-release.csv')

# %%
cart_df.shape
# Out:
# (511, 6)

# %%
cart_df.describe
# Out:
# <bound method NDFrame.describe of      index    State  Rank                    Make/Model  Model Year Thefts
# 0        0  Alabama   1.0  Chevrolet Pickup (Full Size)      2005.0   499
# 1        1  Alabama   2.0       Ford Pickup (Full Size)      2006.0   357
# 2        2  Alabama   3.0                  Toyota Camry      2014.0   205
# 3        3  Alabama   4.0                 Nissan Altima      2014.0   191
# 4        4  Alabama   4.0              Chevrolet Impala      2004.0   191
# ..     ...      ...   ...                           ...         ...    ...
# 506    506  Wyoming   5.0                  Toyota Camry      1997.0     9
# 507    507  Wyoming   6.0                     GMC Yukon      2002.0     8
# 508    508  Wyoming   6.0                  Honda Accord      1997.0     8
# 509    509  Wyoming   7.0            Chevrolet Cavalier      2003.0     6
# 510    510      NaN   NaN                           NaN         NaN    NaN
#
# [511 rows x 6 columns]>

# %%
car_df.head
# Out:
# <bound method NDFrame.head of     index  Theft_Year  Veh Model Yr                        Vehicle # of Thefts
# 0       0        2015          2015                  Nissan Altima       1,104
# 1       1        2015          2015                   Chrysler 200       1,069
# 2       2        2015          2015                   Toyota Camry         923
# 3       3        2015          2015                 Toyota Corolla         776
# 4       4        2015          2015                     GMC Sierra         670
# 5       5        2015          2015                  Dodge Charger         666
# 6       6        2015          2015                 Hyundai Sonata         632
# 7       7        2015          2015               Chevrolet Malibu         629
# 8       8        2015          2015               Chevrolet Impala         594
# 9       9        2015          2015                Chevrolet Cruze         586
# ...

# %%
car_df.describe
# Out:
# <bound method NDFrame.describe of     index  Theft_Year  Veh Model Yr                        Vehicle # of Thefts
# 0       0        2015          2015                  Nissan Altima       1,104
# 1       1        2015          2015                   Chrysler 200       1,069
# 2       2        2015          2015                   Toyota Camry         923
# 3       3        2015          2015                 Toyota Corolla         776
# 4       4        2015          2015                     GMC Sierra         670
# 5       5        2015          2015                  Dodge Charger         666
# 6       6        2015          2015                 Hyundai Sonata         632
# 7       7        2015          2015               Chevrolet Malibu         629
# 8       8        2015          2015               Chevrolet Impala         594
# 9       9        2015          2015                Chevrolet Cruze         586
# ...

# %%
car_df.shape
# Out:
# (25, 5)

# %%
car_df.columns
# Out:
# Index(['index', 'Theft_Year', 'Veh Model Yr', 'Vehicle', '# of Thefts'], dtype='object')

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         25 non-null     int64
#  1   Theft_Year    25 non-null     int64
#  2   Veh Model Yr  25 non-null     int64
#  3   Vehicle       25 non-null     object
#  4   # of Thefts   25 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 1.1+ KB

# %%
car_df
# Out:
#     index  Theft_Year  Veh Model Yr                        Vehicle # of Thefts
# 0       0        2015          2015                  Nissan Altima       1,104
# 1       1        2015          2015                   Chrysler 200       1,069
# 2       2        2015          2015                   Toyota Camry         923
# 3       3        2015          2015                 Toyota Corolla         776
# 4       4        2015          2015                     GMC Sierra         670
# 5       5        2015          2015                  Dodge Charger         666
# 6       6        2015          2015                 Hyundai Sonata         632
# 7       7        2015          2015               Chevrolet Malibu         629
# 8       8        2015          2015               Chevrolet Impala         594
# 9       9        2015          2015                Chevrolet Cruze         586
# 10     10        2015          2015                   Nissan Versa         549
# ...

# %%
car_df.isnull()
# Out:
#     index  Theft_Year  Veh Model Yr  Vehicle  # of Thefts
# 0   False       False         False    False        False
# 1   False       False         False    False        False
# 2   False       False         False    False        False
# 3   False       False         False    False        False
# 4   False       False         False    False        False
# 5   False       False         False    False        False
# 6   False       False         False    False        False
# 7   False       False         False    False        False
# 8   False       False         False    False        False
# 9   False       False         False    False        False
# 10  False       False         False    False        False
# 11  False       False         False    False        False
# 12  False       False         False    False        False
# 13  False       False         False    False        False
# 14  False       False         False    False        False
# ...

# %%
car_df_filtered = car_df.dropna()
car_df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         25 non-null     int64
#  1   Theft_Year    25 non-null     int64
#  2   Veh Model Yr  25 non-null     int64
#  3   Vehicle       25 non-null     object
#  4   # of Thefts   25 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 1.1+ KB
